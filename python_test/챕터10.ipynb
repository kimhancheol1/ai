# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
from mpl_toolkits import mplot3d
import matplotlib.font_manager as mfm
import sympy
D = np.load('data_1d.npz')

# %%
x = D['x']
t = D['t']
X_train = D['X_train']
Y_train = D['Y_train']

X_test = D['X_test']
Y_test = D['Y_test']

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline

model = LinearRegression(fit_intercept=True)
model.fit(X_train[:,np.newaxis],Y_train)
y_sk_lin = model.predict(x[:,np.newaxis])

poly_model = make_pipeline(PolynomialFeatures(P))
poly_model.fit(X_train[:,np.newaxis],Y_train)
y_sk_nonlin = poly_model.predict(x[:,np.newaxis])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 9
#       6 model.fit(X_train[:,np.newaxis],Y_train)
#       7 y_sk_lin = model.predict(x[:,np.newaxis])
# ----> 9 poly_model = make_pipeline(fit_intercept=True)
#      10 poly_model.fit(X_train[:,np.newaxis],Y_train)
#      11 y_sk_nonlin = poly_model.predict(x[:,np.newaxis])
#
# TypeError: make_pipeline() got an unexpected keyword argument 'fit_intercept'

# %%
fig = plt.figure(figsize=(10,7))
ax = fig.add_subplot(1, 1, 1)
ax.xaxis.set_tick_params(labelsize=18)
ax.yaxis.set_tick_params(labelsize=18)
ax.set_xlabel('$x$', fontsize=25)
ax.set_ylabel('$y$', fontsize=25)
ax.grid(False)

ax.plot(x, t, '--', color='k')
ax.plot(X_train, Y_train, 'ko', markersize=8, label='Train data')
ax.plot(X_test, Y_test, 'o', markerfacecolor='w', markeredgecolor='gray', 
       markersize=8, label='Test data')


    
plt.show()
